# %%
# %%capture
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# time: 1.92 ms (started: 2021-08-13 11:29:04 +00:00)

# %% [markdown]
# # Instala a lib Reranker

# %%
# %cd /content/drive/MyDrive/__TCC__Reranker/Reranker/
# Out:
# /content/drive/MyDrive/__TCC__Reranker/Reranker
# time: 7.1 ms (started: 2021-08-13 11:29:18 +00:00)

# %%
# %%capture
# %pip install -e .
# Out:
# time: 13.4 s (started: 2021-08-13 11:29:21 +00:00)

# %% [markdown]
# # Inference

# %% [markdown]
# # prepare input (acho que sõ tem que fazer uma única vez

# %%
# %cd
# %cd /content/drive/MyDrive/__TCC__Reranker/
# %mkdir -p save_output
# !python Reranker/run_msmarco/topk_text_2_json.py \
  --file data/dev.d100.tsv \
  --save_to save_output/all.json \
  --generate_id_to save_output/ids.tsv \
  --tokenizer bert-base-uncased \
  --truncate 512 \
  --q_truncate -1
# Out:
# /root
# /content/drive/MyDrive/__TCC__Reranker
# 2021-08-13 11:29:54.637185: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Downloading: 100% 28.0/28.0 [00:00<00:00, 35.4kB/s]
# Downloading: 100% 570/570 [00:00<00:00, 595kB/s]
# Downloading: 100% 232k/232k [00:00<00:00, 6.02MB/s]
# Downloading: 100% 466k/466k [00:00<00:00, 8.64MB/s]
# Using custom data configuration default-f3450efa39cfac47
# Downloading and preparing dataset csv/default (download: Unknown size, generated: Unknown size, post-processed: Unknown size, total: Unknown size) to /root/.cache/huggingface/datasets/csv/default-f3450efa39cfac47/0.0.0/9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff...
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-f3450efa39cfac47/0.0.0/9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff. Subsequent calls will reuse this data.
# queries are not truncated
# 100% 519300/519300 [21:29<00:00, 402.79it/s]
# time: 23min 25s (started: 2021-08-13 11:29:51 +00:00)
