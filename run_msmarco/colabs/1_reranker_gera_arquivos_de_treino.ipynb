# %%
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# ...
# time: 2.29 ms (started: 2021-07-29 20:43:15 +00:00)

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# time: 6.09 ms (started: 2021-07-29 20:43:15 +00:00)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Select the Runtime > "Change runtime type" menu to enable a GPU accelerator,
# and then re-execute this cell.
# time: 129 ms (started: 2021-07-29 20:43:15 +00:00)

# %% [markdown]
# # Instala a lib Reranker

# %%
# %cd /content/drive/MyDrive/_RERANKER_
# Out:
# /content/drive/MyDrive/_RERANKER_
# time: 9.34 ms (started: 2021-07-29 20:43:15 +00:00)

# %%
# %pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/_RERANKER_
# ...
#      |████████████████████████████████| 2.6 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 542 kB 44.9 MB/s
# ...
#      |████████████████████████████████| 76 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 118 kB 50.9 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 243 kB 42.8 MB/s
# ...
#      |████████████████████████████████| 895 kB 48.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 44.1 MB/s
# ...
#      |████████████████████████████████| 636 kB 42.4 MB/s
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Running setup.py develop for reranker
# ...
# time: 14 s (started: 2021-07-29 20:43:15 +00:00)

# %% [markdown]
# # Roda um exemplo de teste
#
# * Faz dowload do checkpoitn do RoBERTa

# %%
# %cd /content/drive/MyDrive/_RERANKER_
# Out:
# /content/drive/MyDrive/_RERANKER_
# time: 3.51 ms (started: 2021-07-29 20:43:29 +00:00)

# %% [markdown]
# # Gera arquivos de treino

# %%
# !pwd
# Out:
# /content/drive/MyDrive/_RERANKER_
# time: 115 ms (started: 2021-07-29 20:43:29 +00:00)

# %%
# !export HF_DATASETS_CACHE="/content/drive/My Drive/_RERANKER_/data"
# Out:
# time: 114 ms (started: 2021-07-29 20:43:29 +00:00)

# %% [markdown]
# ## Roda todos os arquivos do HDCT

# %% [markdown]
# ToDo: colocar esses comandos num .sh
# * essa parte não precisa de GPU

# %%
# !python examples/msmarco-doc/helpers/build_train_from_ranking.py \
    --tokenizer_name bert-base-uncased \
    --rank_file 	data/hdct-marco-train/014.txt \
    --json_dir data/training_file \
    --n_sample 10 \
    --sample_from_top 100 \
    --random \
    --truncate 512 \
    --qrel data/msmarco-doctrain-qrels.tsv.gz \
    --query_collection data/msmarco-doctrain-queries.tsv \
    --doc_collection data/msmarco-docs.tsv
# Out:
# 2021-07-28 20:33:08.124479: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 0 queries not judged and skipped
# Using custom data configuration default-3d819e5c31d3a1e5
# Reusing dataset csv (/content/drive/My Drive/_RERANKER_/data/csv/default-3d819e5c31d3a1e5/0.0.0/9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff)
# Using custom data configuration default-2fa46c3e85d3bd99
# Reusing dataset csv (/content/drive/My Drive/_RERANKER_/data/csv/default-2fa46c3e85d3bd99/0.0.0/9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff)
# 100% 2000/2000 [03:37<00:00,  9.21it/s]
# time: 9min 11s (started: 2021-07-28 20:33:05 +00:00)

# %%
# !for i in $(seq -f "%03g" 160 183); do python examples/msmarco-doc/helpers/build_train_from_ranking.py --tokenizer_name bert-base-uncased --rank_file 	data/hdct-marco-train/${i}.txt --json_dir data/training_file --n_sample 10 --sample_from_top 100 --random --truncate 512 --qrel data/msmarco-doctrain-qrels.tsv.gz --query_collection data/msmarco-doctrain-queries.tsv --doc_collection data/msmarco-docs.tsv; done
# Out:
# 2021-07-29 20:43:49.093135: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 0 queries not judged and skipped
# Using custom data configuration default-3d819e5c31d3a1e5
# Reusing dataset csv (/content/drive/My Drive/_RERANKER_/data/csv/default-3d819e5c31d3a1e5/0.0.0/9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff)
# Using custom data configuration default-2fa46c3e85d3bd99
# Reusing dataset csv (/content/drive/My Drive/_RERANKER_/data/csv/default-2fa46c3e85d3bd99/0.0.0/9144e0a4e8435090117cea53e6c7537173ef2304525df4a077c435d8ee7828ff)
# Downloading: 100% 28.0/28.0 [00:00<00:00, 19.9kB/s]
# Downloading: 100% 570/570 [00:00<00:00, 432kB/s]
# Downloading: 100% 232k/232k [00:00<00:00, 5.81MB/s]
# Downloading: 100% 466k/466k [00:00<00:00, 8.62MB/s]
# 100% 2000/2000 [03:56<00:00,  8.47it/s]
# ...
