# %%
# %%capture
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# time: 2.14 ms (started: 2021-08-13 11:54:30 +00:00)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Instala a lib Reranker

# %%
# %cd /content/drive/MyDrive/__TCC__Reranker/Reranker/
# Out:
# /content/drive/MyDrive/__TCC__Reranker/Reranker
# time: 5.43 ms (started: 2021-08-13 11:54:38 +00:00)

# %%
# %%capture
# %pip install -e .
# Out:
# time: 13.9 s (started: 2021-08-13 11:54:40 +00:00)

# %% [markdown]
# # Inference

# %%
# %cd
# %cd /content/drive/MyDrive/__TCC__Reranker
# Out:
# /root
# /content/drive/MyDrive/__TCC__Reranker
# time: 4.31 ms (started: 2021-08-13 11:55:03 +00:00)

# %%
# !python Reranker/run_msmarco/run_marco.py \
  --model_name_or_path checkpoints \
  --output_dir score_saving_dir \
  --tokenizer_name bert-base-uncased \
  --do_predict \
  --max_len 512 \
  --fp16 \
  --per_device_eval_batch_size 64 \
  --dataloader_num_workers 8 \
  --pred_path save_output/all.json \
  --pred_id_file  save_output/ids.tsv \
  --rank_score_path score_saving_dir/score.txt
# Out:
# 2021-08-13 11:55:11.937275: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
#
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAa
#
# =========== CONFIGURANDO AS COISAS ===========
# Downloading: 100% 28.0/28.0 [00:00<00:00, 28.3kB/s]
# Downloading: 100% 570/570 [00:00<00:00, 470kB/s]
# Downloading: 100% 232k/232k [00:00<00:00, 1.43MB/s]
# Downloading: 100% 466k/466k [00:00<00:00, 2.79MB/s]
#
# ===========  GETTING DATASET ===========
#
# ===========  INITIALIZING TRAINER ===========
# Using amp fp16 backend
#
# ===========  PREDICTION ===========
# WARNING:datasets.builder:Using custom data configuration default-eb8ee059e4cfd71a
# Downloading and preparing dataset json/default (download: Unknown size, generated: Unknown size, post-processed: Unknown size, total: Unknown size) to /root/.cache/huggingface/datasets/json/default-eb8ee059e4cfd71a/0.0.0/45636811569ec4a6630521c18235dfbbab83b7ab572e3393c5ba68ccabe98264...
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-eb8ee059e4cfd71a/0.0.0/45636811569ec4a6630521c18235dfbbab83b7ab572e3393c5ba68ccabe98264. Subsequent calls will reuse this data.
# ***** Running Prediction *****
#   Num examples = 519300
#   Batch size = 64
# 100% 8114/8115 [44:55<00:00,  3.03it/s]
# ===========  TERMINOU ===========
# 100% 8115/8115 [45:33<00:00,  2.97it/s]
# time: 46min 39s (started: 2021-08-13 11:55:07 +00:00)

# %% [markdown]
# # Gerar score MSMarco

# %%
# %cd
# %cd /content/drive/MyDrive/__TCC__Reranker/
# !python Reranker/run_msmarco/score_to_marco.py --score_file score_saving_dir/score.txt
# Out:
# /root
# /content/drive/MyDrive/__TCC__Reranker
# time: 1.32 s (started: 2021-08-13 12:44:33 +00:00)
